# %%
# %ls
# Out:
# caso1.csv  caso1.ipynb  caso2.csv  caso2.ipynb  parte1/  plant.ipynb

# %%
import pandas
import matplotlib.pyplot as plt

# %%
data = pandas.read_csv('caso2Inundacion.csv')

packets_sent0 = 204
packets_sent1 = 196
packets_sent2 = 225
packets_sent3 = 187
packets_sent4 = 195
packets_sent6 = 165
packets_sent7 = 206

packets_received = 398

# %%
data
# Out:
#                                   run     type                  module
# 0   General-0-20230603-18:07:58-43184  runattr                     NaN  \
# 1   General-0-20230603-18:07:58-43184  runattr                     NaN
# 2   General-0-20230603-18:07:58-43184  runattr                     NaN
# 3   General-0-20230603-18:07:58-43184  runattr                     NaN
# 4   General-0-20230603-18:07:58-43184  runattr                     NaN
# 5   General-0-20230603-18:07:58-43184  runattr                     NaN
# 6   General-0-20230603-18:07:58-43184  runattr                     NaN
# 7   General-0-20230603-18:07:58-43184  runattr                     NaN
# 8   General-0-20230603-18:07:58-43184  runattr                     NaN
# 9   General-0-20230603-18:07:58-43184  runattr                     NaN
# 10  General-0-20230603-18:07:58-43184  runattr                     NaN
# 11  General-0-20230603-18:07:58-43184  runattr                     NaN
# ...

# %%
# Para cada uno de los siguientes, existe para cada intervalo: time_gen ,time_gen0125, time_gen015, time_gen0175,
# time_gen025, time_gen05

# %%
# 0 - 2 - 7 - 1 - 6 - 5
time_queue0lnk0 = data['vectime'].loc[[21]].tolist()
buffer_queue0lnk0 = data['vecvalue'].loc[[21]].tolist()

time_queue0lnk1 = data['vectime'].loc[[22]].tolist()
buffer_queue0lnk1 = data['vecvalue'].loc[[22]].tolist()

time_queue1lnk0 = data['vectime'].loc[[23]].tolist()
buffer_queue1lnk0 = data['vecvalue'].loc[[23]].tolist()

time_queue1lnk1 = data['vectime'].loc[[24]].tolist()
buffer_queue1lnk1 = data['vecvalue'].loc[[24]].tolist()

time_queue2lnk0 = data['vectime'].loc[[25]].tolist()
buffer_queue2lnk0 = data['vecvalue'].loc[[25]].tolist()

time_queue2lnk1 = data['vectime'].loc[[26]].tolist()
buffer_queue2lnk1 = data['vecvalue'].loc[[26]].tolist()

time_queue3lnk0 = data['vectime'].loc[[27]].tolist()
buffer_queue3lnk0 = data['vecvalue'].loc[[27]].tolist()

time_queue3lnk1 = data['vectime'].loc[[28]].tolist()
buffer_queue3lnk1 = data['vecvalue'].loc[[28]].tolist()

time_queue4lnk0 = data['vectime'].loc[[29]].tolist()
buffer_queue4lnk0 = data['vecvalue'].loc[[29]].tolist()

time_queue4lnk1 = data['vectime'].loc[[30]].tolist()
buffer_queue4lnk1 = data['vecvalue'].loc[[30]].tolist()

time_queue5lnk0 = data['vectime'].loc[[31]].tolist()
buffer_queue5lnk0 = data['vecvalue'].loc[[31]].tolist()

time_queue5lnk1 = data['vectime'].loc[[32]].tolist()
buffer_queue5lnk1 = data['vecvalue'].loc[[32]].tolist()

time_queue6lnk0 = data['vectime'].loc[[33]].tolist()
buffer_queue6lnk0 = data['vecvalue'].loc[[33]].tolist()

time_queue6lnk1 = data['vectime'].loc[[34]].tolist()
buffer_queue6lnk1 = data['vecvalue'].loc[[34]].tolist()

time_queue7lnk0 = data['vectime'].loc[[35]].tolist()
buffer_queue7lnk0 = data['vecvalue'].loc[[35]].tolist()

time_queue7lnk1 = data['vectime'].loc[[36]].tolist()
buffer_queue7lnk1 = data['vecvalue'].loc[[36]].tolist()



time_queue0lnk0 = list(map(float, time_queue0lnk0[0].split())) 
buffer_queue0lnk0 = list(map(float,buffer_queue0lnk0[0].split()))

time_queue1lnk0 = list(map(float, time_queue1lnk0[0].split())) 
buffer_queue1lnk0 = list(map(float,buffer_queue1lnk0[0].split()))

time_queue2lnk0 = list(map(float, time_queue2lnk0[0].split())) 
buffer_queue2lnk0 = list(map(float,buffer_queue2lnk0[0].split()))

time_queue3lnk0 = list(map(float, time_queue3lnk0[0].split())) 
buffer_queue3lnk0 = list(map(float,buffer_queue3lnk0[0].split()))

time_queue4lnk0 = list(map(float, time_queue4lnk0[0].split())) 
buffer_queue4lnk0 = list(map(float,buffer_queue4lnk0[0].split()))

time_queue5lnk0 = list(map(float, time_queue5lnk0[0].split())) 
buffer_queue5lnk0 = list(map(float,buffer_queue5lnk0[0].split()))

time_queue6lnk0 = list(map(float, time_queue6lnk0[0].split())) 
buffer_queue6lnk0 = list(map(float,buffer_queue6lnk0[0].split()))

time_queue7lnk0 = list(map(float, time_queue7lnk0[0].split())) 
buffer_queue7lnk0 = list(map(float,buffer_queue7lnk0[0].split()))

time_queue0lnk1 = list(map(float, time_queue0lnk1[0].split())) 
buffer_queue0lnk1 = list(map(float,buffer_queue0lnk1[0].split()))

time_queue1lnk1 = list(map(float, time_queue1lnk1[0].split())) 
buffer_queue1lnk1 = list(map(float,buffer_queue1lnk1[0].split()))

time_queue2lnk1 = list(map(float, time_queue2lnk1[0].split())) 
buffer_queue2lnk1 = list(map(float,buffer_queue2lnk1[0].split()))

time_queue3lnk1 = list(map(float, time_queue3lnk1[0].split())) 
buffer_queue3lnk1 = list(map(float,buffer_queue3lnk1[0].split()))

time_queue4lnk1 = list(map(float, time_queue4lnk1[0].split())) 
buffer_queue4lnk1 = list(map(float,buffer_queue4lnk1[0].split()))

time_queue5lnk1 = list(map(float, time_queue5lnk1[0].split())) 
buffer_queue5lnk1 = list(map(float,buffer_queue5lnk1[0].split()))

time_queue6lnk1 = list(map(float, time_queue6lnk1[0].split())) 
buffer_queue6lnk1 = list(map(float,buffer_queue6lnk1[0].split()))

time_queue7lnk1 = list(map(float, time_queue7lnk1[0].split())) 
buffer_queue7lnk1 = list(map(float,buffer_queue7lnk1[0].split()))


plt.plot(time_queue0lnk0, buffer_queue0lnk0, color='tab:blue', label="Buffer Nodo 0")
plt.plot(time_queue1lnk0, buffer_queue1lnk0, color='tab:red', label="Buffer Nodo 1")
plt.plot(time_queue2lnk0, buffer_queue2lnk0, color='tab:grey', label="Buffer Nodo 2")
plt.plot(time_queue3lnk0, buffer_queue3lnk0, color='tab:orange', label="Buffer Nodo 3")
plt.plot(time_queue4lnk0, buffer_queue4lnk0, color='tab:brown', label="Buffer Nodo 4")
plt.plot(time_queue5lnk0, buffer_queue5lnk0, color='tab:pink', label="Buffer Nodo 5")
plt.plot(time_queue6lnk0, buffer_queue6lnk0, color='tab:purple', label="Buffer Nodo 6")
plt.plot(time_queue7lnk0, buffer_queue7lnk0, color='tab:green', label="Buffer Nodo 7")

plt.title('Ocupacion de buffers lnk0 de la red')
plt.xlabel("Tiempo de simulacion")
plt.ylabel("Cantidad de paquetes en los buffers")
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(time_queue0lnk1, buffer_queue0lnk1, color='tab:blue', label="Buffer Nodo 0")
plt.plot(time_queue1lnk1, buffer_queue1lnk1, color='tab:red', label="Buffer Nodo 1")
plt.plot(time_queue2lnk1, buffer_queue2lnk1, color='tab:grey', label="Buffer Nodo 2")
plt.plot(time_queue3lnk1, buffer_queue3lnk1, color='tab:orange', label="Buffer Nodo 3")
plt.plot(time_queue4lnk1, buffer_queue4lnk1, color='tab:brown', label="Buffer Nodo 4")
plt.plot(time_queue5lnk1, buffer_queue5lnk1, color='tab:pink', label="Buffer Nodo 5")
plt.plot(time_queue6lnk1, buffer_queue6lnk1, color='tab:purple', label="Buffer Nodo 6")
plt.plot(time_queue7lnk1, buffer_queue7lnk1, color='tab:green', label="Buffer Nodo 7")

plt.title('Ocupacion de buffers lnk1 de la red')
plt.xlabel("Tiempo de simulacion")
plt.ylabel("Cantidad de paquetes en los buffers")
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# time_gen05 = list(map(float,time_gen05[0].split()))
# buffer_gen05 = list(map(float,buffer_gen05[0].split()))
# time_queue05 = list(map(float,time_queue05[0].split()))
# buffer_queue05 = list(map(float,buffer_queue05[0].split()))
# time_sink05 = list(map(float,time_sink05[0].split()))
# buffer_sink05 = list(map(float,buffer_sink05[0].split()))
# x_time_delay05 = list(map(float,x_time_delay05[0].split()))
# y_time_delay05 = list(map(float,y_time_delay05[0].split()))
# #ime_packetDrops = list(map(float,time_packetDrops[0].split()))
# #value_packetDrops = list(map(float,value_packetDrops[0].split()))
# time_packetSends05 = list(map(float,time_packetSends05[0].split()))
# value_packetSends05 = list(map(float,value_packetSends05[0].split()))
# time_packetReceived05 = list(map(float,time_packetReceived05[0].split()))
# value_packetReceived05 = list(map(float,value_packetReceived05[0].split()))
# '''

# %%
time_delay = data['vectime'].loc[[37]].tolist()
buffer_delay = data['vecvalue'].loc[[37]].tolist()

time_delay = list(map(float, time_delay[0].split())) 
buffer_delay = list(map(float,buffer_delay[0].split()))

plt.plot(time_delay, buffer_delay, color='tab:green', label="")

plt.title('Demora de la entrega de paquetes')
plt.xlabel("Tiempo de llegada")
plt.ylabel("Demora")
plt.legend()
plt.show
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# cargaOfrecida = [len(value_packetSends)/200, len(value_packetSends0125)/200, len(value_packetSends015)/200,
#                 len(value_packetSends0175)/200, len(value_packetSends025)/200, len(value_packetSends05)/200]
# cargaUtil = [len(value_packetReceived)/200, len(value_packetReceived0125)/200, len(value_packetReceived015)/200,
#             len(value_packetReceived0175)/200, len(value_packetReceived025)/200, len(value_packetReceived05)/200]

# %%
plt.figure(figsize=(8,6))
plt.bar(['Enviados', 'Recibidos'],[packets_sent0 + packets_sent1 + packets_sent2 + packets_sent3 + packets_sent4 + packets_sent6 + packets_sent7, packets_received], color=('b','r'))
plt.title("Paquetes")
plt.show()
